# %% [markdown]
# # Matplotlib
#
# Matplotlib is a very usefull library to make graphs. There are muliple types of graphs available where you can configure axes, ticks, gridline, legends and more details.
#
# You can save the graph as pdf or svg file, so when you zoom in the graph will still be neat. This is not the case with other types of image files that are defined by pixels.
#
# You can make graphs in a jupyter notebook and display it there which is very useful.
#
# Also, Pandas uses matplotlib to make the graphs.
#
# There are a lot of multiple options available to create your graphs. As always, ocumentation will be your friend to create the graphs you need for your projects.

# %% [markdown]
# ## Install
#
# Activate your Python environment and install matplotlib:
#
# ```pip install matplotlib```
#
# ## Documentation
#
# We are going to follow the good tutorial from matplotlib:
#
# https://matplotlib.org/stable/users/explain/quick_start.html#quick-start

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
fig, ax = plt.subplots()  # Create a figure with a simple axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])  # Plot some data

# %% [markdown]
# Let's take a look at the tutorial:
#
# https://matplotlib.org/stable/users/explain/quick_start.html#figure

# %% [markdown]
# Most methods will also parse a string-indexable object like a dict, a structured numpy array, or a pandas.DataFrame.
#
# Matplotlib allows you to provide the data keyword argument and generate plots passing the corresponding strings for x and y variables.

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50), # Return evenly spaced values within a given interval
        'c': np.random.randint(0, 50, 50), # random integers from 0 (inclusive) to 50 (exclusive)
        'd': np.random.randn(50)} # Return a sample from the “standard normal” distribution
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# ## Styling Options
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %%
# Styling artist
data1, data2, data3, data4 = np.random.randn(4, 100) 
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':')

# %% [markdown]
# ## Colors
# https://matplotlib.org/stable/users/explain/colors/colors.html#colors-def

# %%
# Colors
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, facecolor='C0', edgecolor='k')

# %% [markdown]
# ## Axes labels and text

# %%
# Axes labels and text
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')

# data histogram
n, bins, patches = ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
ax.axis([55, 175, 0, 0.03])
ax.grid(True)

# %% [markdown]
# ## Legends

# %%
# legends
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(np.arange(len(data1)), data1, label='data1')
ax.plot(np.arange(len(data2)), data2, label='data2')
ax.plot(np.arange(len(data3)), data3, 'd', label='data3')
ax.legend()

# %% [markdown]
# ## Customizing ticks

# %%
# customizing ticks
xdata = np.arange(len(data1))

fig, axs = plt.subplots(2, 1, layout='constrained')
axs[0].plot(xdata, data1)
axs[0].set_title('Automatic ticks')

axs[1].plot(xdata, data1)
axs[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
axs[1].set_yticks([-1.5, 0, 1.5])  # note that we don't need to specify labels
axs[1].set_title('Manual ticks')
# Out:
# Text(0.5, 1.0, 'Manual ticks')

# %% [markdown]
# ## Additional axis

# %%
# Additional axis
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)

fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(7, 2.7), layout='constrained')
l1, = ax1.plot(t, s)
ax2 = ax1.twinx()
l2, = ax2.plot(t, range(len(t)), 'C1')
ax2.legend([l1, l2], ['Sine (left)', 'Straight (right)'])

ax3.plot(t, s)
ax3.set_xlabel('Angle [rad]')
ax4 = ax3.secondary_xaxis('top', functions=(np.rad2deg, np.deg2rad))
ax4.set_xlabel('Angle [°]')
# Out:
# Text(0.5, 0, 'Angle [°]')

# %% [markdown]
# ## Some types of charts
#
# ### Bar chart
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
#
# ```plt.bar(data, ......)```
#
# ### Pie chart
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html
#
# ```plt.pie(percentage, ....)```

# %% [markdown]
# ## Pandas and Matplotlib

# %% [markdown]
# You may plot series or dataframes
# You may choose the kind of plot (line by default)
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %%
import pandas as pd

# %% [markdown]
# import pandas as pd

# %%
laptops_df = pd.read_csv("laptops.csv")

# %%
laptops_df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
# Plot series
laptops_df.brand.value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
laptops_df.brand.value_counts().plot()
# Out:
# <Axes: xlabel='brand'>

# %%
laptops_df.brand.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='brand'>

# %% [markdown]
# You may plot the entire data frame. It will create a chart with all the columns (could look messy depending on the data).

# %%
laptops_data = laptops_df[["Price", "Number of Ratings"]].sort_values("Number of Ratings", ascending=False).head()

# %%
laptops_data.plot(kind="bar")
# Out:
# <Axes: >

# %%
# Take a look at some styles
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-pastel")

# %%
laptops_data.plot(kind="bar")
# Out:
# <Axes: >

# %%
# Add font size and title
laptops_data.plot(kind="bar", title="My chart", fontsize=12)
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/simon/python/python_envs/env_3.12.1_vscodium/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
df_billboard = pd.read_csv("billboard.csv", parse_dates=["date"])

# %%
df_billboard.head()
# Out:
#         date  rank           song                         artist  last-week  \
# 0 2021-11-06     1     Easy On Me                          Adele        1.0
# 1 2021-11-06     2           Stay  The Kid LAROI & Justin Bieber        2.0
# 2 2021-11-06     3  Industry Baby        Lil Nas X & Jack Harlow        3.0
# 3 2021-11-06     4     Fancy Like                   Walker Hayes        4.0
# 4 2021-11-06     5     Bad Habits                     Ed Sheeran        5.0
#
#    peak-rank  weeks-on-board
# 0          1               3
# 1          1              16
# 2          1              14
# 3          3              19
# 4          2              18
